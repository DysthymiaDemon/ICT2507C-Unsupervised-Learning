# %% [markdown]
# # Exercise 1: MBA
#
# To complete the tasks in this exercise, download the dataset "Market_Basket_Optimisation.csv".

# %% [markdown]
# ## Task 1 - Answer the question
# - What is Market Basket Analysis? Provide an example where this is often used.

# %% [markdown]
# ## Task 2 - Analyze the dataset
# - Perform market basket analysis on the dataset using the apriori algorithm API from the apyori library package.

# %% [markdown]
# ## Task 3 - Interpret results
# - From the results of the analysis done on the dataset, what can you infer from the first result?
